# %%
import pandas as pd
from kafka import KafkaProducer,KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem
import boto3
import s3fs

# %%
consumer= KafkaConsumer('demo_test',bootstrap_servers=['3.87.47.22:9092'],value_deserializer= lambda x:loads(x.decode('utf-8')))

# %%
for c in consumer:
    print(c.value)
# Out:
# {'Index': 'GSPTSE', 'Date': '2004-03-17', 'Open': 8548.0, 'High': 8606.700195, 'Low': 8503.299805, 'Close': 8601.700195, 'Adj Close': 8601.700195, 'Volume': 17327790000.0, 'CloseUSD': 7139.411161849999}
# {'Index': 'NYA', 'Date': '2005-04-22', 'Open': 7047.990234, 'High': 7053.120117, 'Low': 6971.220215, 'Close': 7015.850098, 'Adj Close': 7015.850098, 'Volume': 2045880000.0, 'CloseUSD': 7015.850098}
# {'Index': 'GDAXI', 'Date': '2007-04-18', 'Open': 7341.25, 'High': 7341.25, 'Low': 7243.419922, 'Close': 7282.339844, 'Adj Close': 7282.339844, 'Volume': 133569200.0, 'CloseUSD': 8884.45460968}
# {'Index': 'HSI', 'Date': '1996-06-24', 'Open': 10869.79981, 'High': 10967.0, 'Low': 10841.79981, 'Close': 10959.7002, 'Adj Close': 10959.7002, 'Volume': 0.0, 'CloseUSD': 1424.761026}
# {'Index': 'IXIC', 'Date': '2004-12-08', 'Open': 2118.139893, 'High': 2130.76001, 'Low': 2110.570068, 'Close': 2126.110107, 'Adj Close': 2126.110107, 'Volume': 2390860000.0, 'CloseUSD': 2126.110107}
# ...

# %%
#s3 = boto3.client('s3',aws_access_key_id='AKIASFT6QQA2L4KCBPWN',aws_secret_access_key='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')

# %%
s3=S3FileSystem(key='AKIASFT6QQA2OZMOPV6Y',secret='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')

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://lovi-kafka/stock_market_{}.json".format(count),'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 for count, i in enumerate(consumer):
# ----> 2     with s3.open("s3://lovi-kafka/stock_market_{}.json".format(count),'w') as file:
#       3         json.dump(i.value, file)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\fsspec\spec.py:1834, in AbstractBufferedFile.close(self)
#    1832 else:
#    1833     if not self.forced:
# -> 1834         self.flush(force=True)
#    1836     if self.fs is not None:
#    1837         self.fs.invalidate_cache(self.path)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\fsspec\spec.py:1705, in AbstractBufferedFile.flush(self, force)
#    1702         self.closed = True
#    1703         raise
# -> 1705 if self._upload_chunk(final=force) is not False:
#    1706     self.offset += self.buffer.seek(0, 2)
#    1707     self.buffer = io.BytesIO()
#
# ...
